# %% [markdown]
# # pyBIS Snippets

# %% [markdown]
# ## Connection Settings
# Adjust settings and execute this cell first.

# %%
url    = 'https://main.datastore.bam.de/'
pat    = '' # leave empty to read token from file or authenticate with username
userid = '' # leave empty to use the username from your local machine
space  = '' # leave empty to use the users home space

# %% [markdown]
# ## Connecting
# Use a PAT or username and pasword to connect. A PAT can be specified or read from a file (`OPENBIS_PAT.txt` in current folder or defined by the environment variable `OPENBIS_PAT_FILE`).
#
# After execution the object `o` is the openBIS connection to work with.

# %%
from pybis import Openbis
try:
    from os import environ
    pat = pat or open(environ.get('OPENBIS_PAT_FILE', 'OPENBIS_PAT.txt'), 'r').read().strip()
    o = Openbis(url, token=pat)
    userid = o.token.split('-')[1]
except:
    from getpass import getuser, getpass
    o = Openbis(url)
    userid = userid.lower() or getuser()
    password = getpass('Enter password for user {} at {}: '.format(userid, url))
    o.login(userid, password)
server_info = o.get_server_information()
person = o.get_person(userid)
space = space.upper() or person.space

print('Server: {} (openBIS {}, API {})'.format(o.hostname, server_info.openbis_version, server_info.api_version))
print('UserId: {} ({} {}, {})'.format(person.userId, person.firstName, person.lastName, person.email))
print('Space : {}'.format(space))
# Out:
# Server: main.datastore.bam.de (openBIS 20.10.7.3, API 3.6)
# UserId: cmadaria (Carlos Madariaga, Carlos.Madariaga@bam.de)
# Space : VP.1_CMADARIA

# %% [markdown]
# # Now do something
# Like listing all experimental steps we have access to ...

# %%
o.get_objects(type='EXPERIMENTAL_STEP')
# Out:
#     permId                  identifier                                                   registrationDate     modificationDate     type               registrator    modifier
# --  ----------------------  -----------------------------------------------------------  -------------------  -------------------  -----------------  -------------  ------------
#  0  20241212143551657-8888  /VP.1_ASCHELLE/PROJECT_PYBIS/MEASUREMENT_TEST                2024-12-12 14:35:52  2024-12-12 14:48:07  EXPERIMENTAL_STEP  aschelle       aschelle
#  1  20241212144209347-8892  /VP.1_CDEMIDOV/TEST_PROJECT_PYBIS/TEST_PYBIS_PARENT          2024-12-12 14:42:09  2024-12-12 14:42:09  EXPERIMENTAL_STEP  cdemidov       cdemidov
#  2  20241212144541062-8893  /VP.1_ASCHELLE/PROJECT_PYBIS/MEASUREMENT_1                   2024-12-12 14:45:41  2024-12-12 14:48:07  EXPERIMENTAL_STEP  aschelle       aschelle
#  3  20241212144708316-8894  /VP.1_ASCHELLE/PROJECT_PYBIS/MEASUREMENT_2                   2024-12-12 14:47:08  2024-12-12 14:48:07  EXPERIMENTAL_STEP  aschelle       aschelle
#  4  20241212152150836-8902  /VP.1_CDEMIDOV/IRIS_PROJECT/IRIS_STEP                        2024-12-12 15:21:51  2024-12-12 15:30:47  EXPERIMENTAL_STEP  cdemidov       cdemidov
#  5  20241119131246178-8511  /VP.1_KMEINDL/TEST/EXP5015                                   2024-11-19 13:12:46  2024-11-19 13:12:47  EXPERIMENTAL_STEP  kmeindl        kmeindl
#  6  20241212152714439-8921  /VP.1_CMADARIA/IRIS_PROJECT_C/IRIS_STEP_C                    2024-12-12 15:27:15  2024-12-12 15:31:09  EXPERIMENTAL_STEP  cmadaria       cmadaria
#  7  20241212153224004-8928  /VP.1_CMADARIA/IRIS_PROJECT_C/IRIS_FOO                       2024-12-12 15:32:24  2024-12-12 15:32:24  EXPERIMENTAL_STEP  cmadaria       cmadaria
#  8  20241108185716429-8236  /VP.1_CDEMIDOV/SPIN_CROSSOVER_HEXAAMINEIRON_COMPLEX/EXP4865  2024-11-08 18:57:16  2024-11-08 18:57:43  EXPERIMENTAL_STEP  cdemidov       cdemidov
#  9  20241212153332827-8931  /VP.1_CDEMIDOV/IRIS_PROJECT/IRIS_FOO                         2024-12-12 15:33:33  2025-01-16 09:59:28  EXPERIMENTAL_STEP  cdemidov       cdemidov
# 10  20241212153404380-8938  /VP.1_ASCHELLE/IRIS_PROJECT_A/IRIS_STEP                      2024-12-12 15:34:04  2024-12-12 15:34:04  EXPERIMENTAL_STEP  aschelle       aschelle
# 11  20241212153930740-8947  /VP.1_CMADARIA/PYBIS_ANALYSIS_C/IRIS_ANALYSIS_C              2024-12-12 15:39:31  2024-12-12 15:47:03  EXPERIMENTAL_STEP  cmadaria       cmadaria
# 12  20250121154317268-9072  /VP.1_CDEMIDOV/BAM_RESEARCH/EXP5301                          2025-01-21 15:43:17  2025-01-21 15:43:18  EXPERIMENTAL_STEP  cdemidov_adm   cdemidov_adm
# 13  20241212154026717-8951  /VP.1_CDEMIDOV/PYBIS_ANALYSIS/IRIS_ANALYSIS                  2024-12-12 15:40:27  2024-12-12 15:40:28  EXPERIMENTAL_STEP  cdemidov       cdemidov
# 14  20250121162703952-9073  /VP.1_CDEMIDOV/BAM_RESEARCH/EXP5302                          2025-01-21 16:27:04  2025-01-21 16:27:05  EXPERIMENTAL_STEP  cdemidov_adm   cdemidov_adm
# 15  20250121162747526-9074  /VP.1_CDEMIDOV/BAM_RESEARCH/EXP5303                          2025-01-21 16:27:48  2025-01-21 16:27:48  EXPERIMENTAL_STEP  cdemidov_adm   cdemidov_adm
# 16  20241112091710199-8430  /VP.1_JPIZARRO/TEST2/EXP4958                                 2024-11-12 09:17:10  2024-11-12 09:17:10  EXPERIMENTAL_STEP  jpizarro       jpizarro
# 17  20241112091903181-8431  /VP.1_JPIZARRO/TEST2/EXP4959                                 2024-11-12 09:19:03  2024-11-12 09:19:04  EXPERIMENTAL_STEP  jpizarro       jpizarro
# 18  20241112094423998-8433  /VP.1_JPIZARRO/TEST/EXP4960                                  2024-11-12 09:44:24  2024-12-05 14:42:50  EXPERIMENTAL_STEP  jpizarro       jpizarro
# 19  20241112095441740-8434  /VP.1_JPIZARRO/TEST/EXP4961                                  2024-11-12 09:54:42  2024-11-12 10:06:39  EXPERIMENTAL_STEP  jpizarro       jpizarro
# 20  20241112143345026-8438  /VP.1_JPIZARRO/TEST/EXP4963                                  2024-11-12 14:33:45  2024-11-12 14:33:48  EXPERIMENTAL_STEP  jpizarro       jpizarro
# 21  20241112143346889-8439  /VP.1_JPIZARRO/TEST/EXP4964                                  2024-11-12 14:33:47  2024-11-12 14:33:48  EXPERIMENTAL_STEP  jpizarro       jpizarro
# 22  20241212160737747-8989  /VP.1_CMADARIA/FERTILIZER_IMPACT/MEASUREMENTS                2024-12-12 16:07:38  2024-12-12 16:08:17  EXPERIMENTAL_STEP  cmadaria       cmadaria
# 23  20241212160937143-8993  /VP.1_CMADARIA/FERTILIZER_IMPACT/GROWTH_RESULTS              2024-12-12 16:09:37  2024-12-12 16:09:46  EXPERIMENTAL_STEP  cmadaria       cmadaria
# 24  20241212135438431-8866  /VP.1_CMADARIA/WS_PROJECT/WS_OBJECT                          2024-12-12 13:54:39  2024-12-12 14:43:08  EXPERIMENTAL_STEP  cmadaria       cmadaria
# 25  20241212141331969-8868  /VP.1_CMADARIA/WS_PROJECT/WS_OBJECT_PARENT                   2024-12-12 14:13:32  2024-12-12 14:24:38  EXPERIMENTAL_STEP  cmadaria       cmadaria
# 26  20241212141535768-8876  /VP.1_CMADARIA/WS_PROJECT/WS_OBJECT_CHILD                    2024-12-12 14:15:36  2024-12-12 14:24:38  EXPERIMENTAL_STEP  cmadaria       cmadaria
# 27  20241212142739362-8883  /VP.1_CDEMIDOV/TEST_PROJECT_PYBIS/TEST_PYBIS_NEW             2024-12-12 14:27:39  2024-12-12 15:10:01  EXPERIMENTAL_STEP  cdemidov       cdemidov
# 28  20241212142912040-8884  /VP.1_CDEMIDOV/TEST_PROJECT_PYBIS/CHILD_OBJECT               2024-12-12 14:29:12  2024-12-12 14:29:21  EXPERIMENTAL_STEP  cdemidov       cdemidov

# %% [markdown]
# ## Create and Save a PAT
# If you are logged in with a password you can create and save a PAT here.

# %%
sessionName = 'default'
from datetime import datetime
from os import environ
validFrom = datetime.now() # from now,  or datetime(2024, 12, 17, 10, 30, 0, 0)
validTo   = None # max. time, or datetime(2024, 12, 18, 0, 0, 0, 0)
token = o.get_or_create_personal_access_token(sessionName, validFrom, validTo)
with open(environ.get('OPENBIS_PAT_FILE', 'OPENBIS_PAT.txt'), 'w') as pat_file:
    pat_file.write(token.permId)
print(token.permId)
# Out:
# $pat-cmadaria-250207103133875x7C78CC5A55C30F37CE36D432FFE7113C
